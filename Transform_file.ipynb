# %%
import numpy as np
import pandas as pd
import os

# %%
def read_csv(folder_path):
    files = os.listdir(folder_path)
    df_list = []
    for file in files:
        file_path = os.path.join(folder_path, file)
        df = pd.read_csv(file_path)
        country = file.split('_')[0]
        df['Country'] = country
        df_list.append(df)

    combined_df = pd.concat(df_list, ignore_index = True)
    return combined_df

# %%
folder_path = 'C:/Users/ASUS/Desktop/UIUC/spring courses/Is 597 PR Programming/Final Project/Batter_Data'
batter_df = read_csv(folder_path)

# %%
batter_df
# Out:
#    last_name  first_name  player_id  attempts  avg_hit_angle  \
# 0    Freeman     Freddie     518692        47           11.6
# 1      Betts      Mookie     605141        38           11.1
# 2      Smith        Will     669257        37           13.7
# 3   Martinez        J.D.     502110        35           17.7
# 4      Muncy         Max     571970        26           21.8
# ..       ...         ...        ...       ...            ...
# 69  Conforto     Michael     624424        25           15.2
# 70    Flores      Wilmer     527038        24           23.7
# 71  Pederson         Joc     592626        21           19.2
# 72  Wade Jr.     LaMonte     664774        21           11.8
# 73     Sabol       Blake     666165        19           16.2
#
#     anglesweetspotpercent  max_hit_speed  avg_hit_speed   fbld    gb  \
# 0                    55.3          107.0           90.6   93.2  86.3
# 1                    44.7          108.1           91.8   97.2  85.3
# 2                    40.5          110.8           90.0   95.3  84.0
# 3                    42.9          111.1           96.0   96.8  95.1
# 4                    34.6          111.1           94.7  100.4  89.2
# ..                    ...            ...            ...    ...   ...
# 69                   36.0          109.6           94.4   95.6  92.5
# 70                   37.5          102.2           85.6   90.4  84.9
# 71                   33.3          111.7           97.1  100.4  91.4
# 72                   42.9          111.5           88.6   94.3  82.5
# 73                   15.8          108.5           92.0   92.8  91.2
#
#     max_distance  avg_distance  avg_hr_distance  ev95plus  ev95percent  \
# 0            425           186            396.0        19         41.3
# 1            393           190            389.0        18         47.4
# 2            390           191            373.0        17         47.2
# 3            409           191            409.0        21         60.0
# 4            410           199            389.0        14         53.8
# ..           ...           ...              ...       ...          ...
# 69           429           192            413.0        13         52.0
# 70           392           205            381.0         6         25.0
# 71           432           239            418.0        13         61.9
# 72           394           178            394.0        11         52.4
# 73           434           152            434.0         8         42.1
#
#     barrels  brl_percent  brl_pa    Country
# 0         4          8.5     6.3  Australia
# 1         4         10.5     6.3  Australia
# 2         3          8.1     6.3  Australia
# 3         6         17.1    10.0  Australia
# 4         8         30.8    14.5  Australia
# ..      ...          ...     ...        ...
# 69        3         12.0     6.0  Venezuela
# 70        1          4.2     2.9  Venezuela
# 71        5         23.8    12.5  Venezuela
# 72        3         14.3     7.0  Venezuela
# 73        1          5.3     2.9  Venezuela
#
# [74 rows x 19 columns]

# %%
batter_df.to_csv('batter.csv', index = False)

# %%
folder_path = 'C:/Users/ASUS/Desktop/UIUC/spring courses/Is 597 PR Programming/Final Project/Pitcher_Data'
pitcher_df = read_csv(folder_path)

# %%
pitcher_df
# Out:
#        last_name  first_name  player_id  attempts  avg_hit_angle  \
# 0        Kershaw     Clayton     477132        51            7.1
# 1            May      Dustin     669160        49           15.8
# 2    Syndergaard        Noah     592789        49           13.1
# 3          Urías       Julio     628711        43           13.5
# 4        Jackson       Andre     656578        30           15.0
# ..           ...         ...        ...       ...            ...
# 99     Alexander       Scott     518397        15          -18.0
# 100       Rogers       Tyler     643511        13            6.2
# 101        Doval      Camilo     666808        13            3.8
# 102       Rogers      Taylor     573124        12           27.5
# 103      Brebbia        John     605154        12           26.9
#
#      anglesweetspotpercent  max_hit_speed  avg_hit_speed  fbld    gb  \
# 0                     35.3          107.4           88.5  93.1  84.5
# 1                     26.5          110.1           87.6  89.1  89.4
# 2                     42.9          112.4           86.8  91.6  79.6
# 3                     27.9          108.6           87.5  92.1  83.4
# 4                     43.3          110.3           91.9  93.1  89.7
# ..                     ...            ...            ...   ...   ...
# 99                    26.7          107.3           83.7  93.4  80.2
# 100                   30.8          113.2           88.0  85.8  91.7
# 101                   23.1          115.4           97.7  97.4  99.1
# 102                   25.0          106.1           94.7  98.2  92.4
# 103                   33.3          106.6           92.8  94.5  85.3
#
#      max_distance  avg_distance  avg_hr_distance  ev95plus  ev95percent  \
# 0             432           148            409.0        18         35.3
# 1             380           156              NaN        20         40.8
# 2             393           184            385.0        17         34.7
# 3             389           147            369.0        14         32.6
# 4             423           196            396.0        14         46.7
# ..            ...           ...              ...       ...          ...
# 99            410            96            410.0         4         26.7
# 100           356           143              NaN         5         38.5
# 101           387            99            387.0         7         53.8
# 102           416           250            398.0         7         58.3
# 103           373           260            367.0         6         50.0
#
#      barrels  brl_percent  brl_pa    Country
# 0          5          9.8     6.8  Australia
# 1          3          6.1     4.4  Australia
# 2          4          8.2     5.7  Australia
# 3          1          2.3     1.5  Australia
# 4          5         16.7    13.2  Australia
# ..       ...          ...     ...        ...
# 99         2         13.3    10.5  Venezuela
# 100        1          7.7     5.0  Venezuela
# 101        1          7.7     4.2  Venezuela
# 102        3         25.0    15.8  Venezuela
# 103        1          8.3     4.8  Venezuela
#
# [104 rows x 19 columns]

# %%
pitcher_df.to_csv('pitcher.csv', index = False)
