# %%
import numpy as np
import pandas as pd
import os

# %%
def read_csv(folder_path):
    files = os.listdir(folder_path)
    df_list = []
    for file in files:
        file_path = os.path.join(folder_path, file)
        df = pd.read_csv(file_path)
        country = file.split('_')[0]
        df['Country'] = country
        df_list.append(df)

    combined_df = pd.concat(df_list, ignore_index = True)
    return combined_df

# %%
folder_path = 'C:/Users/ASUS/Desktop/UIUC/spring courses/Is 597 PR Programming/Final Project/Batter_Data'
batter_df = read_csv(folder_path)

# %%
batter_df
# Out:
#        last_name  first_name  player_id  attempts  avg_hit_angle  \
# 0        Arenado       Nolan     571448        56           15.2
# 1        Donovan     Brendan     680977        51            7.4
# 2    Goldschmidt        Paul     502671        49           17.0
# 3         Walker      Jordan     691023        46            3.5
# 4          Edman       Tommy     669242        46           10.2
# ..           ...         ...        ...       ...            ...
# 139       Margot      Manuel     622534        34           17.3
# 140         Lowe     Brandon     664040        33           13.3
# 141  Bethancourt   Christian     542194        27           13.6
# 142        Walls      Taylor     670764        25           23.1
# 143        Raley        Luke     670042        24           19.9
#
#      anglesweetspotpercent  max_hit_speed  avg_hit_speed   fbld    gb  \
# 0                     32.1          108.0           87.8   90.2  86.3
# ...

# %%
batter_df.to_csv('batter.csv', index = False)

# %%
folder_path = 'C:/Users/ASUS/Desktop/UIUC/spring courses/Is 597 PR Programming/Final Project/Pitcher_Data'
pitcher_df = read_csv(folder_path)

# %%
pitcher_df
# Out:
#        last_name  first_name  player_id  year  pa  bip     ba  est_ba  \
# 0        Kershaw     Clayton     477132  2023  73   51  0.239   0.250
# 1    Syndergaard        Noah     592789  2023  70   49  0.273   0.253
# 2            May      Dustin     669160  2023  68   49  0.115   0.221
# 3          Urías       Julio     628711  2023  66   43  0.210   0.180
# 4          Grove     Michael     675627  2023  58   39  0.302   0.233
# ..           ...         ...        ...   ...  ..  ...    ...     ...
# 98        Rogers       Tyler     643511  2023  27   18  0.042   0.181
# 99       Brebbia        John     605154  2023  25   15  0.273   0.216
# 100        Doval      Camilo     666808  2023  24   13  0.200   0.205
# 101       Rogers      Taylor     573124  2023  20   13  0.357   0.313
# 102    Alexander       Scott     518397  2023  19   15  0.211   0.315
#
#      est_ba_minus_ba_diff    slg  est_slg  est_slg_minus_slg_diff   woba  \
# ...

# %%
pitcher_df.to_csv('pitcher.csv', index = False)
